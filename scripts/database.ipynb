# %% [markdown]
# # Routing Data ETL Pipeline Tutorial
#
# This notebook demonstrates the complete workflow for processing routing problems into our DuckDB database:
#
# 1. **Setup & Initialization** - Import APIs and create database
# 2. **Parse TSPLIB95 Problems** - Process TSP, ATSP, HCP, SOP, TOUR instances
# 3. **Process VRP Problems** - Add CVRPLIB VRP instances
# 4. **Convert MDVRP Format** - Convert Cordeau MDVRP to TSPLIB95
# 5. **Query & Analysis** - Retrieve and analyze stored problems
#
# ## Key Features Demonstrated
#
# - ✅ **EXPLICIT edge weights** (ATSP) stored in `edge_weight_matrices` table
# - ✅ **Coordinate-based problems** (TSP) with on-demand distance calculation
# - ✅ **VRP variants** with capacity, time windows, depots
# - ✅ **MDVRP conversion** from Cordeau format
# - ✅ **Batch processing** for multiple files
# - ✅ **Database queries** and export

# %% [markdown]
# ## 1. Setup & Imports
#
# First, we'll import our ETL pipeline components and initialize the database.

# %%
import sys
from pathlib import Path

# Add src/ directory to path (not project root)
# This matches how the package is installed via pyproject.toml
project_root = Path.cwd().parent
sys.path.insert(0, str(project_root / 'src'))

# Import our ETL pipeline components
from tsplib_parser.parser import FormatParser
from converter.core.transformer import DataTransformer
from converter.database.operations import DatabaseManager
from converter.utils.logging import setup_logging

# Setup logging
logger = setup_logging(level="INFO")

print("✅ Imports successful!")
print(f"📁 Project root: {project_root}")
print(f"📁 src/ added to path: {project_root / 'src'}")
print(f"📁 Database will be created in: {project_root / 'datasets' / 'db'}")
# Out:
# ✅ Imports successful!
# 📁 Project root: /home/lucas_galdino/TCC-name_to_define/Routing_data
# 📁 Database will be created in: /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets/db

# %%
# Initialize database
db_path = project_root / "datasets" / "db" / "routing_tutorial.duckdb"

# Create fresh database (remove old one if exists)
if db_path.exists():
    db_path.unlink()
    print(f"🗑️  Removed old database")

db = DatabaseManager(db_path=str(db_path), logger=logger)
print(f"✅ Database initialized: {db_path}")

# Show schema
import duckdb
with duckdb.connect(str(db_path)) as conn:
    tables = conn.execute("SHOW TABLES").fetchall()
    print(f"\n📊 Database tables created:")
    for table in tables:
        print(f"   - {table[0]}")
# Out:
# 🗑️  Removed old database
# 2025-10-28 15:08:11,117 - converter - INFO - Database schema initialized at /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets/db/routing_tutorial.duckdb
# ✅ Database initialized: /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets/db/routing_tutorial.duckdb
#
# 📊 Database tables created:
#    - edge_weight_matrices
#    - file_tracking
#    - nodes
#    - problems
#    - solutions
# ✅ Database initialized: /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets/db/routing_tutorial.duckdb
#
# 📊 Database tables created:
#    - edge_weight_matrices
#    - file_tracking
#    - nodes
#    - problems
#    - solutions

# %% [markdown]
# ## 2. Parse & Insert Problems from `datasets_raw/problems/`
#
# We'll start with the TSPLIB95 standard problems: TSP, ATSP, HCP, SOP, and TOUR instances.
#
# ### 2.1 Parse a TSP Problem (Coordinate-based: EUC_2D)
#
# **Important**: TSPLIB95 problems come in two main types:
# - **Coordinate-based** (e.g., EUC_2D): Nodes have x,y coordinates, distances computed on-demand
# - **EXPLICIT**: Distance matrix provided directly, nodes may lack coordinates
#
# We'll start with berlin52.tsp which uses **EUC_2D** (Euclidean 2D distances from coordinates).

# %%
# Step 1: Parse TSPLIB95 file (coordinate-based TSP)
tsp_file = project_root / "datasets_raw/problems/tsp/berlin52.tsp"
parser = FormatParser(logger=logger)

parsed_data = parser.parse_file(str(tsp_file))
print(f"✅ Parsed {tsp_file.name}")
print(f"   Problem type: {parsed_data['problem_data']['type']}")
print(f"   Dimension: {parsed_data['problem_data']['dimension']}")
print(f"   Edge weight type: {parsed_data['problem_data'].get('edge_weight_type', 'N/A')}")
print(f"   Nodes: {len(parsed_data['nodes'])}")

# Show first 3 nodes (should have coordinates!)
print("\n📍 First 3 nodes (with coordinates):")
for node in parsed_data['nodes'][:3]:
    print(f"   Node {node.get('node_id', node.get('id', '?'))}: x={node.get('x')}, y={node.get('y')}")
# Out:
# 2025-10-28 15:08:11,162 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/berlin52.tsp: TSP with 52 nodes
# ✅ Parsed berlin52.tsp
#    Problem type: TSP
#    Dimension: 52
#    Edge weight type: EUC_2D
#    Nodes: 52
#
# 📍 First 3 nodes (with coordinates):
#    Node 0: x=565.0, y=575.0
#    Node 1: x=25.0, y=185.0
#    Node 2: x=345.0, y=750.0
# ✅ Parsed berlin52.tsp
#    Problem type: TSP
#    Dimension: 52
#    Edge weight type: EUC_2D
#    Nodes: 52
#
# 📍 First 3 nodes (with coordinates):
#    Node 0: x=565.0, y=575.0
#    Node 1: x=25.0, y=185.0
#    Node 2: x=345.0, y=750.0

# %%
# Step 2: Transform data
# - Normalizes structure (adds missing fields with defaults)
# - Converts node IDs from 1-based (TSPLIB95) to 0-based (database)
# - Processes edge weights if EXPLICIT (not needed for EUC_2D)
transformer = DataTransformer(logger=logger)
transformed_data = transformer.transform_problem(parsed_data)

print("✅ Data transformed")
print(f"   Keys in transformed data: {list(transformed_data.keys())}")
print(f"   Node ID conversion: TSPLIB95 uses 1-based, database uses 0-based")

# For EUC_2D problems, NO edge_weight_matrix is created
# Distances are computed on-demand from node coordinates using Euclidean formula
if 'edge_weight_matrix' in transformed_data:
    print(f"   ⚠️  Edge weight matrix: {len(transformed_data['edge_weight_matrix'])}×{len(transformed_data['edge_weight_matrix'][0])}")
else:
    print(f"   ℹ️  No edge_weight_matrix (coordinate-based problem)")
    print(f"   ℹ️  Distances computed on-demand from (x,y) coordinates")
# Out:
# ✅ Data transformed
#    Keys in transformed data: ['problem_data', 'nodes', 'tours', 'metadata']
#    Node ID conversion: TSPLIB95 uses 1-based, database uses 0-based
#    ℹ️  No edge_weight_matrix (coordinate-based problem)
#    ℹ️  Distances computed on-demand from (x,y) coordinates

# %%
# Step 3: Insert into database
# Note: insert_problem() only takes problem_data, not file_path
# For production code with file tracking, use insert_problem_atomic() instead
problem_id = db.insert_problem(transformed_data['problem_data'])
print(f"✅ Problem inserted with ID: {problem_id}")

# Insert nodes
node_count = db.insert_nodes(problem_id, transformed_data['nodes'])
print(f"✅ Inserted {node_count} nodes")

# Insert tours if present
if transformed_data.get('tours'):
    tour_count = db.insert_tours(problem_id, transformed_data['tours'])
    print(f"✅ Inserted {tour_count} tours")

print(f"\n🎉 Successfully added {tsp_file.name} to database!")

# Verify insertion
import duckdb
with duckdb.connect(str(db_path)) as conn:
    result = conn.execute("""
        SELECT p.name, p.dimension, COUNT(n.node_id) as node_count
        FROM problems p
        LEFT JOIN nodes n ON p.id = n.problem_id
        WHERE p.id = ?
        GROUP BY p.name, p.dimension
    """, [problem_id]).fetchone()
    print(f"\n✅ Verification: {result[0]} has {result[2]}/{result[1]} nodes in database")
# Out:
# ✅ Problem inserted with ID: 1
# ✅ Inserted 52 nodes
#
# 🎉 Successfully added berlin52.tsp to database!
#
# ✅ Verification: berlin52 has 52/52 nodes in database

# %% [markdown]
# ### 2.2 Parse an ATSP Problem (EXPLICIT Edge Weights)
#
# Now let's process an ATSP problem which has **EXPLICIT** edge weights (distance matrix provided directly).
#
# **Key Differences from EUC_2D**:
# - **EXPLICIT problems**: Distance matrix stored in file, not computed
# - **ATSP (Asymmetric TSP)**: Distance A→B ≠ Distance B→A
# - **No coordinates**: Nodes may not have x,y values (just node IDs)
# - **Matrix storage**: Edge weights stored in `edge_weight_matrices` table

# %%
# IMPORTANT: Reload transformer module after code fix
import sys
import importlib

# Remove cached modules
modules_to_reload = [k for k in sys.modules.keys() if 'transformer' in k or 'matrix' in k.lower()]
for mod in modules_to_reload:
    del sys.modules[mod]

# Now re-import
from src.converter.core import transformer as transformer_module
transformer = transformer_module.DataTransformer(logger=logger)
print("✅ Reloaded transformer module with Matrix.value_at() fix")
print(f"   Removed {len(modules_to_reload)} cached modules")
# Out:
# ✅ Reloaded transformer module with Matrix.value_at() fix
#    Removed 5 cached modules

# %%
# Parse ATSP file (EXPLICIT edge weights)
atsp_file = project_root / "datasets_raw/problems/atsp/br17.atsp"

parsed_atsp = parser.parse_file(str(atsp_file))
transformed_atsp = transformer.transform_problem(parsed_atsp)

print(f"✅ Parsed {atsp_file.name}")
print(f"   Problem type: {transformed_atsp['problem_data']['type']}")
print(f"   Edge weight type: {transformed_atsp['problem_data']['edge_weight_type']}")
print(f"   Edge weight format: {transformed_atsp['problem_data']['edge_weight_format']}")

# Check for edge weight matrix
if 'edge_weight_matrix' in transformed_atsp:
    matrix = transformed_atsp['edge_weight_matrix']
    print(f"\n📊 Edge weight matrix: {len(matrix)}×{len(matrix[0])}")
    print(f"   Matrix size in bytes: {len(str(matrix))}")
    print(f"   Sample distances (0-based indexing):")
    print(f"      Distance [0→1]: {matrix[0][1]}")
    print(f"      Distance [1→0]: {matrix[1][0]}")
    print(f"      Asymmetric? {matrix[0][1] != matrix[1][0]}")
else:
    print("   ⚠️  No edge_weight_matrix found (unexpected for ATSP!)")
# Out:
# 2025-10-28 15:08:11,818 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/atsp/br17.atsp: ATSP with 17 nodes
# 2025-10-28 15:08:11,820 - converter - INFO - Converted edge weights to 17×17 matrix
# ✅ Parsed br17.atsp
#    Problem type: ATSP
#    Edge weight type: EXPLICIT
#    Edge weight format: FULL_MATRIX
#
# 📊 Edge weight matrix: 17×17
#    Matrix size in bytes: 1024
#    Sample distances (0-based indexing):
#       Distance [0→1]: 3
#       Distance [1→0]: 3
#       Asymmetric? False
# 2025-10-28 15:08:11,820 - converter - INFO - Converted edge weights to 17×17 matrix
# ✅ Parsed br17.atsp
#    Problem type: ATSP
#    Edge weight type: EXPLICIT
#    Edge weight format: FULL_MATRIX
#
# 📊 Edge weight matrix: 17×17
#    Matrix size in bytes: 1024
#    Sample distances (0-based indexing):
#       Distance [0→1]: 3
#       Distance [1→0]: 3
#       Asymmetric? False

# %%
# Insert ATSP problem into database
atsp_id = db.insert_problem(transformed_atsp['problem_data'])
print(f"✅ ATSP problem inserted with ID: {atsp_id}")

# Insert nodes (ATSP may have no coordinates, just node IDs)
node_count = db.insert_nodes(atsp_id, transformed_atsp['nodes'])
print(f"✅ Inserted {node_count} nodes")

# Insert edge weight matrix (if present - should be for EXPLICIT problems)
if 'edge_weight_matrix' in transformed_atsp:
    import json
    matrix = transformed_atsp['edge_weight_matrix']
    dimension = transformed_atsp['problem_data']['dimension']
    matrix_format = transformed_atsp['problem_data'].get('edge_weight_format', 'FULL_MATRIX')
    is_symmetric = transformed_atsp['problem_data']['type'] != 'ATSP'  # ATSP is asymmetric
    
    # Insert into edge_weight_matrices table
    with duckdb.connect(str(db_path)) as conn:
        conn.execute("""
            INSERT INTO edge_weight_matrices (problem_id, dimension, matrix_format, is_symmetric, matrix_json)
            VALUES (?, ?, ?, ?, ?)
        """, [atsp_id, dimension, matrix_format, is_symmetric, json.dumps(matrix)])
    
    print(f"✅ Inserted {dimension}×{dimension} edge weight matrix into edge_weight_matrices table")
else:
    print(f"ℹ️  No edge weight matrix (coordinate-based problem)")

print(f"\n🎉 Successfully added {atsp_file.name} with EXPLICIT edge weights!")

# Verify matrix storage
if 'edge_weight_matrix' in transformed_atsp:
    with duckdb.connect(str(db_path)) as conn:
        matrix_info = conn.execute("""
            SELECT dimension, matrix_format, is_symmetric, LENGTH(matrix_json) as size_bytes
            FROM edge_weight_matrices
            WHERE problem_id = ?
        """, [atsp_id]).fetchone()
        if matrix_info:
            print(f"\n✅ Verification: {matrix_info[0]}×{matrix_info[0]} {matrix_info[1]} matrix")
            print(f"   Symmetric: {matrix_info[2]}, Size: {matrix_info[3]:,} bytes")
# Out:
# ✅ ATSP problem inserted with ID: 2
# ✅ Inserted 17 nodes
# ✅ Inserted 17×17 edge weight matrix into edge_weight_matrices table
#
# 🎉 Successfully added br17.atsp with EXPLICIT edge weights!
#
# ✅ Verification: 17×17 FULL_MATRIX matrix
#    Symmetric: False, Size: 1,024 bytes

# %% [markdown]
# ### 2.3 Batch Process All Problems from `datasets_raw/problems/`
#
# Now let's process all TSP, ATSP, HCP, and SOP files in bulk.
#
# **Note on API**: We use `insert_problem(problem_data)` which takes only the problem data dictionary. For EXPLICIT problems (ATSP), edge weight matrices are inserted manually via SQL into the `edge_weight_matrices` table.
#
# **Alternative**: For production code with file tracking, use `insert_problem_atomic()` which handles problem, nodes, and edge matrices in a single transaction with file_path and checksum parameters.

# %%
from src.converter.core.scanner import FileScanner

# Scan problems/ directory for all TSPLIB95 files
problems_dir = project_root / "datasets_raw/problems"
scanner = FileScanner(logger=logger)

# Scan for all problem types (excluding the files we already added)
all_files = scanner.scan_files(
    directory=str(problems_dir),
    patterns=['*.tsp', '*.atsp', '*.hcp', '*.sop', '*.tour'],
    recursive=True
)

print(f"📁 Found {len(all_files)} files in {problems_dir.name}/")

# Filter out files we already processed
already_processed = {'gr17.tsp', 'br17.atsp'} # bad implementation to keep track of what was already added
to_process = [f for f in all_files if Path(f).name not in already_processed]

print(f"📋 Will process {len(to_process)} new files (skipping {len(already_processed)} already added)")
print(f"\nFile breakdown by extension:")
for ext in ['.tsp', '.atsp', '.hcp', '.sop', '.tour']:
    count = sum(1 for f in to_process if f.endswith(ext))
    if count > 0:
        print(f"   {ext}: {count} files")

'''
No vrp files found yet
'''
# Out:
# 2025-10-28 15:08:12,025 - converter - INFO - Found 223 files
# 📁 Found 223 files in problems/
# 📋 Will process 221 new files (skipping 2 already added)
#
# File breakdown by extension:
#    .tsp: 112 files
#    .atsp: 18 files
#    .hcp: 9 files
#    .sop: 41 files
#    .tour: 41 files
# 📁 Found 223 files in problems/
# 📋 Will process 221 new files (skipping 2 already added)
#
# File breakdown by extension:
#    .tsp: 112 files
#    .atsp: 18 files
#    .hcp: 9 files
#    .sop: 41 files
#    .tour: 41 files
# '\nNo vrp files found yet\n'

# %%
# Process all files in batch
success_count = 0
error_count = 0
errors = []

for file_path in to_process:
    try:
        # Parse
        parsed = parser.parse_file(file_path)
        
        # Transform
        transformed = transformer.transform_problem(parsed)
        
        # Insert problem (NO file_path parameter)
        prob_id = db.insert_problem(transformed['problem_data'])
        
        # Insert nodes
        db.insert_nodes(prob_id, transformed['nodes'])
        
        # Insert tours if present
        if transformed.get('tours'):
            db.insert_tours(prob_id, transformed['tours'])
        
        # Insert edge weight matrix if present (EXPLICIT problems like ATSP)
        if 'edge_weight_matrix' in transformed:
            import json
            matrix = transformed['edge_weight_matrix']
            dimension = transformed['problem_data']['dimension']
            matrix_format = transformed['problem_data'].get('edge_weight_format', 'FULL_MATRIX')
            is_symmetric = transformed['problem_data']['type'] != 'ATSP'
            
            with duckdb.connect(str(db_path)) as conn:
                conn.execute("""
                    INSERT INTO edge_weight_matrices (problem_id, dimension, matrix_format, is_symmetric, matrix_json)
                    VALUES (?, ?, ?, ?, ?)
                """, [prob_id, dimension, matrix_format, is_symmetric, json.dumps(matrix)])
        
        success_count += 1
        if success_count % 50 == 0:
            print(f"   ✅ Processed {success_count}/{len(to_process)} files...")
            
    except Exception as e:
        error_count += 1
        errors.append((Path(file_path).name, str(e)))
        if error_count <= 5:  # Show first 5 errors
            print(f"   ❌ Error processing {Path(file_path).name}: {e}")

print(f"\n✅ Successfully processed {success_count}/{len(to_process)} files")
if error_count > 0:
    print(f"❌ Errors: {error_count}")
    if error_count > 5:
        print(f"   (Showing first 5 errors only)")
# Out:
# 2025-10-28 15:08:12,187 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/xray14012_2.tsp: TSP with 14012 nodes
# 2025-10-28 15:08:44,143 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/u1817.tsp: TSP with 1817 nodes
# 2025-10-28 15:08:44,143 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/u1817.tsp: TSP with 1817 nodes
# 2025-10-28 15:08:48,248 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/berlin52.tsp: TSP with 52 nodes
# 2025-10-28 15:08:48,248 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/berlin52.tsp: TSP with 52 nodes
# 2025-10-28 15:08:48,441 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/att532.tsp: TSP with 532 nodes
# 2025-10-28 15:08:48,441 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/att532.tsp: TSP with 532 nodes
# 2025-10-28 15:08:49,722 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/d657.tsp: TSP with 657 nodes
# 2025-10-28 15:08:49,722 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/d657.tsp: TSP with 657 nodes
# 2025-10-28 15:08:51,368 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/pcb3038.tsp: TSP with 3038 nodes
# 2025-10-28 15:08:51,368 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/pcb3038.tsp: TSP with 3038 nodes
# 2025-10-28 15:08:58,377 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/bayg29.tsp: TSP with 29 nodes
# 2025-10-28 15:08:58,379 - converter - INFO - Converted edge weights to 29×29 matrix
# 2025-10-28 15:08:58,377 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/bayg29.tsp: TSP with 29 nodes
# 2025-10-28 15:08:58,379 - converter - INFO - Converted edge weights to 29×29 matrix
# 2025-10-28 15:08:58,570 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/fnl4461.tsp: TSP with 4461 nodes
# 2025-10-28 15:08:58,570 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/fnl4461.tsp: TSP with 4461 nodes
# 2025-10-28 15:09:08,472 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/u159.tsp: TSP with 159 nodes
# 2025-10-28 15:09:08,472 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/u159.tsp: TSP with 159 nodes
# 2025-10-28 15:09:08,891 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/eil101.tsp: TSP with 101 nodes
# 2025-10-28 15:09:08,891 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/eil101.tsp: TSP with 101 nodes
# 2025-10-28 15:09:09,203 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/ali535.tsp: TSP with 535 nodes
# 2025-10-28 15:09:09,203 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/ali535.tsp: TSP with 535 nodes
# 2025-10-28 15:09:10,594 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/usa13509.tsp: TSP with 13509 nodes
# 2025-10-28 15:09:10,594 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/usa13509.tsp: TSP with 13509 nodes
# 2025-10-28 15:09:40,957 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/pcb442.tsp: TSP with 442 nodes
# 2025-10-28 15:09:40,957 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/pcb442.tsp: TSP with 442 nodes
# 2025-10-28 15:09:41,994 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/d493.tsp: TSP with 493 nodes
# 2025-10-28 15:09:41,994 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/d493.tsp: TSP with 493 nodes
# 2025-10-28 15:09:43,106 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/vm1748.tsp: TSP with 1748 nodes
# 2025-10-28 15:09:43,106 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/vm1748.tsp: TSP with 1748 nodes
# 2025-10-28 15:09:47,104 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/eil51.tsp: TSP with 51 nodes
# 2025-10-28 15:09:47,104 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/eil51.tsp: TSP with 51 nodes
# 2025-10-28 15:09:47,300 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/pr264.tsp: TSP with 264 nodes
# 2025-10-28 15:09:47,300 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/pr264.tsp: TSP with 264 nodes
# 2025-10-28 15:09:47,998 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/d1291.tsp: TSP with 1291 nodes
# 2025-10-28 15:09:47,998 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/d1291.tsp: TSP with 1291 nodes
# 2025-10-28 15:09:50,944 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/p654.tsp: TSP with 654 nodes
# 2025-10-28 15:09:50,944 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/p654.tsp: TSP with 654 nodes
# 2025-10-28 15:09:52,643 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/a280.tsp: TSP with 280 nodes
# 2025-10-28 15:09:52,643 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/a280.tsp: TSP with 280 nodes
# 2025-10-28 15:09:53,313 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/gr48.tsp: TSP with 48 nodes
# 2025-10-28 15:09:53,315 - converter - INFO - Converted edge weights to 48×48 matrix
# 2025-10-28 15:09:53,313 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/gr48.tsp: TSP with 48 nodes
# 2025-10-28 15:09:53,315 - converter - INFO - Converted edge weights to 48×48 matrix
# 2025-10-28 15:09:53,541 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/att48.tsp: TSP with 48 nodes
# 2025-10-28 15:09:53,541 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/att48.tsp: TSP with 48 nodes
# 2025-10-28 15:09:53,795 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/pla7397.tsp: TSP with 7397 nodes
# 2025-10-28 15:09:53,795 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/pla7397.tsp: TSP with 7397 nodes
# 2025-10-28 15:10:10,695 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/rl1889.tsp: TSP with 1889 nodes
# 2025-10-28 15:10:10,695 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/rl1889.tsp: TSP with 1889 nodes
# 2025-10-28 15:10:14,826 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/d198.tsp: TSP with 198 nodes
# 2025-10-28 15:10:14,826 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/d198.tsp: TSP with 198 nodes
# 2025-10-28 15:10:15,357 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/pr439.tsp: TSP with 439 nodes
# 2025-10-28 15:10:15,357 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/pr439.tsp: TSP with 439 nodes
# 2025-10-28 15:10:16,422 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/rd100.tsp: TSP with 100 nodes
# 2025-10-28 15:10:16,422 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/rd100.tsp: TSP with 100 nodes
# 2025-10-28 15:10:16,739 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/fl1400.tsp: TSP with 1400 nodes
# 2025-10-28 15:10:16,739 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/fl1400.tsp: TSP with 1400 nodes
# 2025-10-28 15:10:20,020 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/kroC100.tsp: TSP with 100 nodes
# 2025-10-28 15:10:20,020 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/kroC100.tsp: TSP with 100 nodes
# 2025-10-28 15:10:20,327 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/kroE100.tsp: TSP with 100 nodes
# 2025-10-28 15:10:20,327 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/kroE100.tsp: TSP with 100 nodes
# 2025-10-28 15:10:20,632 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/linhp318.tsp: TSP with 318 nodes
# 2025-10-28 15:10:20,632 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/linhp318.tsp: TSP with 318 nodes
# 2025-10-28 15:10:21,473 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/rl5915.tsp: TSP with 5915 nodes
# 2025-10-28 15:10:21,473 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/rl5915.tsp: TSP with 5915 nodes
# 2025-10-28 15:10:35,368 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/pr152.tsp: TSP with 152 nodes
# 2025-10-28 15:10:35,368 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/pr152.tsp: TSP with 152 nodes
# 2025-10-28 15:10:35,833 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/kroB100.tsp: TSP with 100 nodes
# 2025-10-28 15:10:35,833 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/kroB100.tsp: TSP with 100 nodes
# 2025-10-28 15:10:36,194 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/kroA200.tsp: TSP with 200 nodes
# 2025-10-28 15:10:36,194 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/kroA200.tsp: TSP with 200 nodes
# 2025-10-28 15:10:36,799 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/rl1304.tsp: TSP with 1304 nodes
# 2025-10-28 15:10:36,799 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/rl1304.tsp: TSP with 1304 nodes
# 2025-10-28 15:10:40,081 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/d1655.tsp: TSP with 1655 nodes
# 2025-10-28 15:10:40,081 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/d1655.tsp: TSP with 1655 nodes
# 2025-10-28 15:10:44,017 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/fri26.tsp: TSP with 26 nodes
# 2025-10-28 15:10:44,018 - converter - INFO - Converted edge weights to 26×26 matrix
# 2025-10-28 15:10:44,017 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/fri26.tsp: TSP with 26 nodes
# 2025-10-28 15:10:44,018 - converter - INFO - Converted edge weights to 26×26 matrix
# 2025-10-28 15:10:44,228 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/dantzig42.tsp: TSP with 42 nodes
# 2025-10-28 15:10:44,231 - converter - INFO - Converted edge weights to 42×42 matrix
# 2025-10-28 15:10:44,228 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/dantzig42.tsp: TSP with 42 nodes
# 2025-10-28 15:10:44,231 - converter - INFO - Converted edge weights to 42×42 matrix
# 2025-10-28 15:10:44,483 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/gr120.tsp: TSP with 120 nodes
# 2025-10-28 15:10:44,494 - converter - INFO - Converted edge weights to 120×120 matrix
# 2025-10-28 15:10:44,483 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/gr120.tsp: TSP with 120 nodes
# 2025-10-28 15:10:44,494 - converter - INFO - Converted edge weights to 120×120 matrix
# 2025-10-28 15:10:44,949 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/rl5934.tsp: TSP with 5934 nodes
# 2025-10-28 15:10:44,949 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/rl5934.tsp: TSP with 5934 nodes
# 2025-10-28 15:10:58,648 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/u724.tsp: TSP with 724 nodes
# 2025-10-28 15:10:58,648 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/u724.tsp: TSP with 724 nodes
# 2025-10-28 15:11:00,440 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/fl417.tsp: TSP with 417 nodes
# 2025-10-28 15:11:00,440 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/fl417.tsp: TSP with 417 nodes
# 2025-10-28 15:11:01,490 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/pr136.tsp: TSP with 136 nodes
# 2025-10-28 15:11:01,490 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/pr136.tsp: TSP with 136 nodes
# 2025-10-28 15:11:01,949 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/rat195.tsp: TSP with 195 nodes
# 2025-10-28 15:11:01,949 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/rat195.tsp: TSP with 195 nodes
# 2025-10-28 15:11:02,538 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/rl1323.tsp: TSP with 1323 nodes
# 2025-10-28 15:11:02,538 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/rl1323.tsp: TSP with 1323 nodes
# 2025-10-28 15:11:05,614 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/kroA150.tsp: TSP with 150 nodes
# 2025-10-28 15:11:05,614 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/kroA150.tsp: TSP with 150 nodes
# 2025-10-28 15:11:06,082 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/rat575.tsp: TSP with 575 nodes
# 2025-10-28 15:11:06,082 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/rat575.tsp: TSP with 575 nodes
# 2025-10-28 15:11:07,583 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/d18512.tsp: TSP with 18512 nodes
# 2025-10-28 15:11:07,583 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/d18512.tsp: TSP with 18512 nodes
# 2025-10-28 15:11:50,923 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/pr144.tsp: TSP with 144 nodes
# 2025-10-28 15:11:50,923 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/pr144.tsp: TSP with 144 nodes
#    ✅ Processed 50/221 files...
# 2025-10-28 15:11:51,393 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/rd400.tsp: TSP with 400 nodes
#    ✅ Processed 50/221 files...
# 2025-10-28 15:11:51,393 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/rd400.tsp: TSP with 400 nodes
# 2025-10-28 15:11:52,627 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/ch130.tsp: TSP with 130 nodes
# 2025-10-28 15:11:52,627 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/ch130.tsp: TSP with 130 nodes
# 2025-10-28 15:11:53,118 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/rl11849.tsp: TSP with 11849 nodes
# 2025-10-28 15:11:53,118 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/rl11849.tsp: TSP with 11849 nodes
# 2025-10-28 15:12:20,488 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/kroD100.tsp: TSP with 100 nodes
# 2025-10-28 15:12:20,488 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/kroD100.tsp: TSP with 100 nodes
# 2025-10-28 15:12:20,860 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/nrw1379.tsp: TSP with 1379 nodes
# 2025-10-28 15:12:20,860 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/nrw1379.tsp: TSP with 1379 nodes
# 2025-10-28 15:12:24,008 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/gr96.tsp: TSP with 96 nodes
# 2025-10-28 15:12:24,008 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/gr96.tsp: TSP with 96 nodes
# 2025-10-28 15:12:24,363 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/gr21.tsp: TSP with 21 nodes
# 2025-10-28 15:12:24,365 - converter - INFO - Converted edge weights to 21×21 matrix
# 2025-10-28 15:12:24,363 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/gr21.tsp: TSP with 21 nodes
# 2025-10-28 15:12:24,365 - converter - INFO - Converted edge weights to 21×21 matrix
# 2025-10-28 15:12:24,617 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/lin318.tsp: TSP with 318 nodes
# 2025-10-28 15:12:24,617 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/lin318.tsp: TSP with 318 nodes
# 2025-10-28 15:12:25,465 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/pr299.tsp: TSP with 299 nodes
# 2025-10-28 15:12:25,465 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/pr299.tsp: TSP with 299 nodes
# 2025-10-28 15:12:26,321 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/bier127.tsp: TSP with 127 nodes
# 2025-10-28 15:12:26,321 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/bier127.tsp: TSP with 127 nodes
# 2025-10-28 15:12:26,712 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/tsp225.tsp: TSP with 225 nodes
# 2025-10-28 15:12:26,712 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/tsp225.tsp: TSP with 225 nodes
# 2025-10-28 15:12:27,377 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/fl3795.tsp: TSP with 3795 nodes
# 2025-10-28 15:12:27,377 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/fl3795.tsp: TSP with 3795 nodes
# 2025-10-28 15:12:36,481 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/pcb1173.tsp: TSP with 1173 nodes
# 2025-10-28 15:12:36,481 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/pcb1173.tsp: TSP with 1173 nodes
# 2025-10-28 15:12:39,233 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/gil262.tsp: TSP with 262 nodes
# 2025-10-28 15:12:39,233 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/gil262.tsp: TSP with 262 nodes
# 2025-10-28 15:12:39,970 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/rat783.tsp: TSP with 783 nodes
# 2025-10-28 15:12:39,970 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/rat783.tsp: TSP with 783 nodes
# 2025-10-28 15:12:41,898 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/burma14.tsp: TSP with 14 nodes
# 2025-10-28 15:12:41,898 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/burma14.tsp: TSP with 14 nodes
# 2025-10-28 15:12:42,095 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/pr1002.tsp: TSP with 1002 nodes
# 2025-10-28 15:12:42,095 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/pr1002.tsp: TSP with 1002 nodes
# 2025-10-28 15:12:44,510 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/ulysses16.tsp: TSP with 16 nodes
# 2025-10-28 15:12:44,510 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/ulysses16.tsp: TSP with 16 nodes
# 2025-10-28 15:12:44,699 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/pr76.tsp: TSP with 76 nodes
# 2025-10-28 15:12:44,699 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/pr76.tsp: TSP with 76 nodes
# 2025-10-28 15:12:45,026 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/brazil58.tsp: TSP with 58 nodes
# 2025-10-28 15:12:45,030 - converter - INFO - Converted edge weights to 58×58 matrix
# 2025-10-28 15:12:45,026 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/brazil58.tsp: TSP with 58 nodes
# 2025-10-28 15:12:45,030 - converter - INFO - Converted edge weights to 58×58 matrix
# 2025-10-28 15:12:45,380 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/pr226.tsp: TSP with 226 nodes
# 2025-10-28 15:12:45,380 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/pr226.tsp: TSP with 226 nodes
# 2025-10-28 15:12:46,302 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/pla33810.tsp: TSP with 33810 nodes
# 2025-10-28 15:12:46,302 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/pla33810.tsp: TSP with 33810 nodes
# 2025-10-28 15:14:03,110 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/gr24.tsp: TSP with 24 nodes
# 2025-10-28 15:14:03,112 - converter - INFO - Converted edge weights to 24×24 matrix
# 2025-10-28 15:14:03,110 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/gr24.tsp: TSP with 24 nodes
# 2025-10-28 15:14:03,112 - converter - INFO - Converted edge weights to 24×24 matrix
# 2025-10-28 15:14:03,396 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/vm1084.tsp: TSP with 1084 nodes
# 2025-10-28 15:14:03,396 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/vm1084.tsp: TSP with 1084 nodes
# 2025-10-28 15:14:05,995 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/kroB150.tsp: TSP with 150 nodes
# 2025-10-28 15:14:05,995 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/kroB150.tsp: TSP with 150 nodes
# 2025-10-28 15:14:06,529 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/d2103.tsp: TSP with 2103 nodes
# 2025-10-28 15:14:06,529 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/d2103.tsp: TSP with 2103 nodes
# 2025-10-28 15:14:11,394 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/swiss42.tsp: TSP with 42 nodes
# 2025-10-28 15:14:11,396 - converter - INFO - Converted edge weights to 42×42 matrix
# 2025-10-28 15:14:11,394 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/swiss42.tsp: TSP with 42 nodes
# 2025-10-28 15:14:11,396 - converter - INFO - Converted edge weights to 42×42 matrix
# 2025-10-28 15:14:11,781 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/brd14051.tsp: TSP with 14051 nodes
# 2025-10-28 15:14:11,781 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/brd14051.tsp: TSP with 14051 nodes
# 2025-10-28 15:14:44,311 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/rat99.tsp: TSP with 99 nodes
# 2025-10-28 15:14:44,311 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/rat99.tsp: TSP with 99 nodes
# 2025-10-28 15:14:44,695 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/u2319.tsp: TSP with 2319 nodes
# 2025-10-28 15:14:44,695 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/u2319.tsp: TSP with 2319 nodes
# 2025-10-28 15:14:50,013 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/si175.tsp: TSP with 175 nodes
# 2025-10-28 15:14:50,013 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/si175.tsp: TSP with 175 nodes
# 2025-10-28 15:14:50,062 - converter - INFO - Converted edge weights to 175×175 matrix
# 2025-10-28 15:14:50,062 - converter - INFO - Converted edge weights to 175×175 matrix
# 2025-10-28 15:14:50,731 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/ulysses22.tsp: TSP with 22 nodes
# 2025-10-28 15:14:50,731 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/ulysses22.tsp: TSP with 22 nodes
# 2025-10-28 15:14:50,927 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/gr229.tsp: TSP with 229 nodes
# 2025-10-28 15:14:50,927 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/gr229.tsp: TSP with 229 nodes
# 2025-10-28 15:14:52,019 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/si1032.tsp: TSP with 1032 nodes
# 2025-10-28 15:14:52,019 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/si1032.tsp: TSP with 1032 nodes
# 2025-10-28 15:14:53,512 - converter - INFO - Converted edge weights to 1032×1032 matrix
# 2025-10-28 15:14:53,512 - converter - INFO - Converted edge weights to 1032×1032 matrix
# 2025-10-28 15:14:56,364 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/bays29.tsp: TSP with 29 nodes
# 2025-10-28 15:14:56,365 - converter - INFO - Converted edge weights to 29×29 matrix
# 2025-10-28 15:14:56,364 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/bays29.tsp: TSP with 29 nodes
# 2025-10-28 15:14:56,365 - converter - INFO - Converted edge weights to 29×29 matrix
# 2025-10-28 15:14:56,668 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/lin105.tsp: TSP with 105 nodes
# 2025-10-28 15:14:56,668 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/lin105.tsp: TSP with 105 nodes
# 2025-10-28 15:14:57,096 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/u1432.tsp: TSP with 1432 nodes
# 2025-10-28 15:14:57,096 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/u1432.tsp: TSP with 1432 nodes
# 2025-10-28 15:15:00,610 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/brg180.tsp: TSP with 180 nodes
# 2025-10-28 15:15:00,610 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/brg180.tsp: TSP with 180 nodes
# 2025-10-28 15:15:00,648 - converter - INFO - Converted edge weights to 180×180 matrix
# 2025-10-28 15:15:00,648 - converter - INFO - Converted edge weights to 180×180 matrix
# 2025-10-28 15:15:01,319 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/dsj1000.tsp: TSP with 1000 nodes
# 2025-10-28 15:15:01,319 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/dsj1000.tsp: TSP with 1000 nodes
# 2025-10-28 15:15:03,867 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/kroB200.tsp: TSP with 200 nodes
# 2025-10-28 15:15:03,867 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/kroB200.tsp: TSP with 200 nodes
# 2025-10-28 15:15:04,503 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/pr124.tsp: TSP with 124 nodes
# 2025-10-28 15:15:04,503 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/pr124.tsp: TSP with 124 nodes
# 2025-10-28 15:15:04,951 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/gr666.tsp: TSP with 666 nodes
# 2025-10-28 15:15:04,951 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/gr666.tsp: TSP with 666 nodes
# 2025-10-28 15:15:06,610 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/kroA100.tsp: TSP with 100 nodes
# 2025-10-28 15:15:06,610 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/kroA100.tsp: TSP with 100 nodes
# 2025-10-28 15:15:07,085 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/si535.tsp: TSP with 535 nodes
# 2025-10-28 15:15:07,085 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/si535.tsp: TSP with 535 nodes
# 2025-10-28 15:15:07,440 - converter - INFO - Converted edge weights to 535×535 matrix
# 2025-10-28 15:15:07,440 - converter - INFO - Converted edge weights to 535×535 matrix
# 2025-10-28 15:15:09,146 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/hk48.tsp: TSP with 48 nodes
# 2025-10-28 15:15:09,148 - converter - INFO - Converted edge weights to 48×48 matrix
# 2025-10-28 15:15:09,146 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/hk48.tsp: TSP with 48 nodes
# 2025-10-28 15:15:09,148 - converter - INFO - Converted edge weights to 48×48 matrix
# 2025-10-28 15:15:09,509 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/ch150.tsp: TSP with 150 nodes
# 2025-10-28 15:15:09,509 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/ch150.tsp: TSP with 150 nodes
# 2025-10-28 15:15:10,078 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/fl1577.tsp: TSP with 1577 nodes
# 2025-10-28 15:15:10,078 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/fl1577.tsp: TSP with 1577 nodes
# 2025-10-28 15:15:13,734 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/u1060.tsp: TSP with 1060 nodes
# 2025-10-28 15:15:13,734 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/u1060.tsp: TSP with 1060 nodes
# 2025-10-28 15:15:16,238 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/pr107.tsp: TSP with 107 nodes
# 2025-10-28 15:15:16,238 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/pr107.tsp: TSP with 107 nodes
# 2025-10-28 15:15:16,715 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/d15112.tsp: TSP with 15112 nodes
# 2025-10-28 15:15:16,715 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/d15112.tsp: TSP with 15112 nodes
#    ✅ Processed 100/221 files...
# 2025-10-28 15:15:51,393 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/gr431.tsp: TSP with 431 nodes
#    ✅ Processed 100/221 files...
# 2025-10-28 15:15:51,393 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/gr431.tsp: TSP with 431 nodes
# 2025-10-28 15:15:53,207 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/pla85900.tsp: TSP with 85900 nodes
# 2025-10-28 15:15:53,207 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/pla85900.tsp: TSP with 85900 nodes
# 2025-10-28 15:19:25,003 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/u2152.tsp: TSP with 2152 nodes
# 2025-10-28 15:19:25,003 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/u2152.tsp: TSP with 2152 nodes
# 2025-10-28 15:19:30,635 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/ts225.tsp: TSP with 225 nodes
# 2025-10-28 15:19:30,635 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/ts225.tsp: TSP with 225 nodes
# 2025-10-28 15:19:31,341 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/st70.tsp: TSP with 70 nodes
# 2025-10-28 15:19:31,341 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/st70.tsp: TSP with 70 nodes
# 2025-10-28 15:19:31,880 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/xray14012_1.tsp: TSP with 14012 nodes
# 2025-10-28 15:19:31,880 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/xray14012_1.tsp: TSP with 14012 nodes
# 2025-10-28 15:20:05,707 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/pa561.tsp: TSP with 561 nodes
# 2025-10-28 15:20:05,707 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/pa561.tsp: TSP with 561 nodes
# 2025-10-28 15:20:06,025 - converter - INFO - Converted edge weights to 561×561 matrix
# 2025-10-28 15:20:06,025 - converter - INFO - Converted edge weights to 561×561 matrix
# 2025-10-28 15:20:07,726 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/pr2392.tsp: TSP with 2392 nodes
# 2025-10-28 15:20:07,726 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/pr2392.tsp: TSP with 2392 nodes
# 2025-10-28 15:20:13,306 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/gr202.tsp: TSP with 202 nodes
# 2025-10-28 15:20:13,306 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/gr202.tsp: TSP with 202 nodes
# 2025-10-28 15:20:13,959 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/gr137.tsp: TSP with 137 nodes
# 2025-10-28 15:20:13,959 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/gr137.tsp: TSP with 137 nodes
# 2025-10-28 15:20:14,424 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/u574.tsp: TSP with 574 nodes
# 2025-10-28 15:20:14,424 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/u574.tsp: TSP with 574 nodes
# 2025-10-28 15:20:15,837 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/eil76.tsp: TSP with 76 nodes
# 2025-10-28 15:20:15,837 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tsp/eil76.tsp: TSP with 76 nodes
# 2025-10-28 15:20:16,175 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/atsp/ftv64.atsp: ATSP with 65 nodes
# 2025-10-28 15:20:16,177 - converter - INFO - Converted edge weights to 65×65 matrix
# 2025-10-28 15:20:16,175 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/atsp/ftv64.atsp: ATSP with 65 nodes
# 2025-10-28 15:20:16,177 - converter - INFO - Converted edge weights to 65×65 matrix
# 2025-10-28 15:20:16,697 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/atsp/rbg403.atsp: ATSP with 403 nodes
# 2025-10-28 15:20:16,697 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/atsp/rbg403.atsp: ATSP with 403 nodes
# 2025-10-28 15:20:16,752 - converter - INFO - Converted edge weights to 403×403 matrix
# 2025-10-28 15:20:16,752 - converter - INFO - Converted edge weights to 403×403 matrix
# 2025-10-28 15:20:18,007 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/atsp/rbg358.atsp: ATSP with 358 nodes
# 2025-10-28 15:20:18,007 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/atsp/rbg358.atsp: ATSP with 358 nodes
# 2025-10-28 15:20:18,049 - converter - INFO - Converted edge weights to 358×358 matrix
# 2025-10-28 15:20:18,049 - converter - INFO - Converted edge weights to 358×358 matrix
# 2025-10-28 15:20:19,110 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/atsp/ftv70.atsp: ATSP with 71 nodes
# 2025-10-28 15:20:19,114 - converter - INFO - Converted edge weights to 71×71 matrix
# 2025-10-28 15:20:19,110 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/atsp/ftv70.atsp: ATSP with 71 nodes
# 2025-10-28 15:20:19,114 - converter - INFO - Converted edge weights to 71×71 matrix
# 2025-10-28 15:20:19,556 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/atsp/ftv35.atsp: ATSP with 36 nodes
# 2025-10-28 15:20:19,557 - converter - INFO - Converted edge weights to 36×36 matrix
# 2025-10-28 15:20:19,556 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/atsp/ftv35.atsp: ATSP with 36 nodes
# 2025-10-28 15:20:19,557 - converter - INFO - Converted edge weights to 36×36 matrix
# 2025-10-28 15:20:19,901 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/atsp/ftv38.atsp: ATSP with 39 nodes
# 2025-10-28 15:20:19,902 - converter - INFO - Converted edge weights to 39×39 matrix
# 2025-10-28 15:20:19,901 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/atsp/ftv38.atsp: ATSP with 39 nodes
# 2025-10-28 15:20:19,902 - converter - INFO - Converted edge weights to 39×39 matrix
# 2025-10-28 15:20:20,252 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/atsp/ft53.atsp: ATSP with 53 nodes
# 2025-10-28 15:20:20,254 - converter - INFO - Converted edge weights to 53×53 matrix
# 2025-10-28 15:20:20,252 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/atsp/ft53.atsp: ATSP with 53 nodes
# 2025-10-28 15:20:20,254 - converter - INFO - Converted edge weights to 53×53 matrix
# 2025-10-28 15:20:20,651 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/atsp/ftv47.atsp: ATSP with 48 nodes
# 2025-10-28 15:20:20,653 - converter - INFO - Converted edge weights to 48×48 matrix
# 2025-10-28 15:20:20,651 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/atsp/ftv47.atsp: ATSP with 48 nodes
# 2025-10-28 15:20:20,653 - converter - INFO - Converted edge weights to 48×48 matrix
# 2025-10-28 15:20:21,141 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/atsp/rbg443.atsp: ATSP with 443 nodes
# 2025-10-28 15:20:21,141 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/atsp/rbg443.atsp: ATSP with 443 nodes
# 2025-10-28 15:20:21,207 - converter - INFO - Converted edge weights to 443×443 matrix
# 2025-10-28 15:20:21,207 - converter - INFO - Converted edge weights to 443×443 matrix
# 2025-10-28 15:20:22,529 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/atsp/ftv55.atsp: ATSP with 56 nodes
# 2025-10-28 15:20:22,531 - converter - INFO - Converted edge weights to 56×56 matrix
# 2025-10-28 15:20:22,529 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/atsp/ftv55.atsp: ATSP with 56 nodes
# 2025-10-28 15:20:22,531 - converter - INFO - Converted edge weights to 56×56 matrix
# 2025-10-28 15:20:22,920 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/atsp/p43.atsp: ATSP with 43 nodes
# 2025-10-28 15:20:22,921 - converter - INFO - Converted edge weights to 43×43 matrix
# 2025-10-28 15:20:22,920 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/atsp/p43.atsp: ATSP with 43 nodes
# 2025-10-28 15:20:22,921 - converter - INFO - Converted edge weights to 43×43 matrix
# 2025-10-28 15:20:23,306 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/atsp/ftv170.atsp: ATSP with 171 nodes
# 2025-10-28 15:20:23,306 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/atsp/ftv170.atsp: ATSP with 171 nodes
# 2025-10-28 15:20:23,323 - converter - INFO - Converted edge weights to 171×171 matrix
# 2025-10-28 15:20:23,323 - converter - INFO - Converted edge weights to 171×171 matrix
# ...
#    ❌ Error processing kro124p.4.sop: Failed to parse /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/sop/kro124p.4.sop: FullMatrix with dimension 101 requires 10201 elements, but got 10202
#    ❌ Error processing ESC11.sop: Failed to parse /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/sop/ESC11.sop: FullMatrix with dimension 13 requires 169 elements, but got 170
#    ❌ Error processing ESC63.sop: Failed to parse /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/sop/ESC63.sop: FullMatrix with dimension 65 requires 4225 elements, but got 4226
#    ❌ Error processing ft53.4.sop: Failed to parse /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/sop/ft53.4.sop: FullMatrix with dimension 54 requires 2916 elements, but got 2917
#    ❌ Error processing p43.1.sop: Failed to parse /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/sop/p43.1.sop: FullMatrix with dimension 44 requires 1936 elements, but got 1937
#    ❌ Error processing kro124p.4.sop: Failed to parse /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/sop/kro124p.4.sop: FullMatrix with dimension 101 requires 10201 elements, but got 10202
# 2025-10-28 15:21:32,778 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/pr2392.opt.tour: TOUR with 2392 nodes
# 2025-10-28 15:21:32,778 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/pr2392.opt.tour: TOUR with 2392 nodes
# 2025-10-28 15:21:38,372 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/kroD100.opt.tour: TOUR with 100 nodes
# 2025-10-28 15:21:38,372 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/kroD100.opt.tour: TOUR with 100 nodes
# 2025-10-28 15:21:38,764 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/bayg29.opt.tour: TOUR with 29 nodes
# 2025-10-28 15:21:38,764 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/bayg29.opt.tour: TOUR with 29 nodes
# 2025-10-28 15:21:39,020 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/gr666.opt.tour: TOUR with 666 nodes
# 2025-10-28 15:21:39,020 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/gr666.opt.tour: TOUR with 666 nodes
# 2025-10-28 15:21:40,653 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/gr202.opt.tour: TOUR with 202 nodes
# 2025-10-28 15:21:40,653 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/gr202.opt.tour: TOUR with 202 nodes
# 2025-10-28 15:21:41,290 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/alb3000d.opt.tour: TOUR with 3000 nodes
# 2025-10-28 15:21:41,290 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/alb3000d.opt.tour: TOUR with 3000 nodes
# 2025-10-28 15:21:48,438 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/alb5000.opt.tour: TOUR with 5000 nodes
# 2025-10-28 15:21:48,438 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/alb5000.opt.tour: TOUR with 5000 nodes
# 2025-10-28 15:22:00,490 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/gr48.opt.tour: TOUR with 48 nodes
# 2025-10-28 15:22:00,490 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/gr48.opt.tour: TOUR with 48 nodes
# 2025-10-28 15:22:00,839 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/tsp225.opt.tour: TOUR with 225 nodes
# 2025-10-28 15:22:00,839 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/tsp225.opt.tour: TOUR with 225 nodes
# 2025-10-28 15:22:01,597 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/alb4000.opt.tour: TOUR with 4000 nodes
# 2025-10-28 15:22:01,597 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/alb4000.opt.tour: TOUR with 4000 nodes
# 2025-10-28 15:22:10,915 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/gr96.opt.tour: TOUR with 96 nodes
# 2025-10-28 15:22:10,915 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/gr96.opt.tour: TOUR with 96 nodes
# 2025-10-28 15:22:11,334 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/pcb442.opt.tour: TOUR with 442 nodes
# 2025-10-28 15:22:11,334 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/pcb442.opt.tour: TOUR with 442 nodes
# 2025-10-28 15:22:12,498 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/alb3000e.opt.tour: TOUR with 3000 nodes
# 2025-10-28 15:22:12,498 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/alb3000e.opt.tour: TOUR with 3000 nodes
# 2025-10-28 15:22:19,348 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/ch150.opt.tour: TOUR with 150 nodes
# 2025-10-28 15:22:19,348 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/ch150.opt.tour: TOUR with 150 nodes
# 2025-10-28 15:22:19,883 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/pr76.opt.tour: TOUR with 76 nodes
# 2025-10-28 15:22:19,883 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/pr76.opt.tour: TOUR with 76 nodes
# 2025-10-28 15:22:20,275 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/gr24.opt.tour: TOUR with 24 nodes
# 2025-10-28 15:22:20,275 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/gr24.opt.tour: TOUR with 24 nodes
# 2025-10-28 15:22:20,549 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/st70.opt.tour: TOUR with 70 nodes
# 2025-10-28 15:22:20,549 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/st70.opt.tour: TOUR with 70 nodes
# 2025-10-28 15:22:20,945 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/brg180.opt.tour: TOUR with 180 nodes
# 2025-10-28 15:22:20,945 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/brg180.opt.tour: TOUR with 180 nodes
# 2025-10-28 15:22:21,568 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/eil51.opt.tour: TOUR with 51 nodes
# 2025-10-28 15:22:21,568 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/eil51.opt.tour: TOUR with 51 nodes
# 2025-10-28 15:22:21,922 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/kroC100.opt.tour: TOUR with 100 nodes
# 2025-10-28 15:22:21,922 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/kroC100.opt.tour: TOUR with 100 nodes
# 2025-10-28 15:22:22,406 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/alb1000.opt.tour: TOUR with 1000 nodes
# 2025-10-28 15:22:22,406 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/alb1000.opt.tour: TOUR with 1000 nodes
# 2025-10-28 15:22:25,083 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/eil76.opt.tour: TOUR with 76 nodes
# 2025-10-28 15:22:25,083 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/eil76.opt.tour: TOUR with 76 nodes
# 2025-10-28 15:22:25,548 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/fri26.opt.tour: TOUR with 26 nodes
# 2025-10-28 15:22:25,548 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/fri26.opt.tour: TOUR with 26 nodes
# 2025-10-28 15:22:25,891 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/alb3000c.opt.tour: TOUR with 3000 nodes
# 2025-10-28 15:22:25,891 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/alb3000c.opt.tour: TOUR with 3000 nodes
# 2025-10-28 15:22:33,750 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/lin105.opt.tour: TOUR with 105 nodes
# 2025-10-28 15:22:33,750 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/lin105.opt.tour: TOUR with 105 nodes
# 2025-10-28 15:22:34,251 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/berlin52.opt.tour: TOUR with 52 nodes
# 2025-10-28 15:22:34,251 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/berlin52.opt.tour: TOUR with 52 nodes
# 2025-10-28 15:22:34,567 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/ch130.opt.tour: TOUR with 130 nodes
# 2025-10-28 15:22:34,567 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/ch130.opt.tour: TOUR with 130 nodes
# 2025-10-28 15:22:35,066 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/a280.opt.tour: TOUR with 280 nodes
# 2025-10-28 15:22:35,066 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/a280.opt.tour: TOUR with 280 nodes
# 2025-10-28 15:22:35,910 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/alb3000a.opt.tour: TOUR with 3000 nodes
# 2025-10-28 15:22:35,910 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/alb3000a.opt.tour: TOUR with 3000 nodes
# 2025-10-28 15:22:42,812 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/att48.opt.tour: TOUR with 48 nodes
# 2025-10-28 15:22:42,812 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/att48.opt.tour: TOUR with 48 nodes
# 2025-10-28 15:22:43,147 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/pr1002.opt.tour: TOUR with 1002 nodes
# 2025-10-28 15:22:43,147 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/pr1002.opt.tour: TOUR with 1002 nodes
# 2025-10-28 15:22:45,508 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/pa561.opt.tour: TOUR with 561 nodes
# 2025-10-28 15:22:45,508 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/pa561.opt.tour: TOUR with 561 nodes
# 2025-10-28 15:22:47,062 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/bays29.opt.tour: TOUR with 29 nodes
# 2025-10-28 15:22:47,062 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/bays29.opt.tour: TOUR with 29 nodes
# 2025-10-28 15:22:47,362 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/gr120.opt.tour: TOUR with 120 nodes
# 2025-10-28 15:22:47,362 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/gr120.opt.tour: TOUR with 120 nodes
# 2025-10-28 15:22:47,896 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/eil101.opt.tour: TOUR with 101 nodes
# 2025-10-28 15:22:47,896 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/eil101.opt.tour: TOUR with 101 nodes
# 2025-10-28 15:22:48,391 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/alb3000b.opt.tour: TOUR with 3000 nodes
# 2025-10-28 15:22:48,391 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/alb3000b.opt.tour: TOUR with 3000 nodes
# 2025-10-28 15:22:56,008 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/kroA100.opt.tour: TOUR with 100 nodes
# 2025-10-28 15:22:56,008 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/kroA100.opt.tour: TOUR with 100 nodes
# 2025-10-28 15:22:56,465 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/ulysses16.opt.tour: TOUR with 16 nodes
# 2025-10-28 15:22:56,465 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/ulysses16.opt.tour: TOUR with 16 nodes
# 2025-10-28 15:22:56,741 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/alb2000.opt.tour: TOUR with 2000 nodes
# 2025-10-28 15:22:56,741 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/alb2000.opt.tour: TOUR with 2000 nodes
# 2025-10-28 15:23:01,305 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/ulysses22.opt.tour: TOUR with 22 nodes
# 2025-10-28 15:23:01,305 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/problems/tour/ulysses22.opt.tour: TOUR with 22 nodes
#
# ✅ Successfully processed 139/221 files
# ❌ Errors: 82
#    (Showing first 5 errors only)
#
# ✅ Successfully processed 139/221 files
# ❌ Errors: 82
#    (Showing first 5 errors only)

# %%
print(errors)

# %% [markdown]
# ## 3. Add VRP-set-D Problems (CVRPLIB)
#
# Now let's process the VRP instances from CVRPLIB's VRP-set-D (Loggi and ORTEC instances).
#
# **VRP Characteristics**:
# - Coordinate-based (EUC_2D) with capacity constraints
# - Depot nodes identified by `is_depot=True` flag in nodes table
# - No separate depots table needed

# %%
# Scan VRP-set-D directory
vrp_set_d_dir = project_root / "datasets_raw/cvrplib/VRP-set-D"

vrp_files = scanner.scan_files(
    directory=str(vrp_set_d_dir),
    patterns=['*.vrp'],
    recursive=False
)

print(f"📁 Found {len(vrp_files)} VRP files in VRP-set-D/")
print(f"\nSample files:")
for f in vrp_files[:5]:
    print(f"   - {Path(f).name}")
# Out:
# 2025-10-28 15:23:01,582 - converter - INFO - Found 12 files
# 📁 Found 12 VRP files in VRP-set-D/
#
# Sample files:
#    - ORTEC-n510-k23.vrp
#    - Loggi-n1001-k31.vrp
#    - Loggi-n401-k23.vrp
#    - ORTEC-n405-k18.vrp
#    - Loggi-n601-k42.vrp
# 📁 Found 12 VRP files in VRP-set-D/
#
# Sample files:
#    - ORTEC-n510-k23.vrp
#    - Loggi-n1001-k31.vrp
#    - Loggi-n401-k23.vrp
#    - ORTEC-n405-k18.vrp
#    - Loggi-n601-k42.vrp

# %%
# Process VRP-set-D files
vrp_success = 0
vrp_errors = []

for vrp_file in vrp_files:
    try:
        parsed = parser.parse_file(vrp_file)
        transformed = transformer.transform_problem(parsed)
        
        # Insert problem (NO file_path parameter)
        prob_id = db.insert_problem(transformed['problem_data'])
        db.insert_nodes(prob_id, transformed['nodes'])
        
        # VRP problems may have depot information in the nodes (is_depot flag)
        # No separate depots table insertion needed
        
        vrp_success += 1
        
    except Exception as e:
        vrp_errors.append((Path(vrp_file).name, str(e)))
        if len(vrp_errors) <= 3:
            print(f"❌ Error: {Path(vrp_file).name}: {e}")

print(f"✅ Successfully processed {vrp_success}/{len(vrp_files)} VRP files")
if vrp_errors:
    print(f"❌ Errors: {len(vrp_errors)}")
# Out:
# 2025-10-28 15:23:01,706 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/cvrplib/VRP-set-D/ORTEC-n510-k23.vrp: CVRP with 510 nodes
# 2025-10-28 15:23:01,957 - converter - INFO - Converted edge weights to 510×510 matrix
# 2025-10-28 15:23:01,957 - converter - INFO - Converted edge weights to 510×510 matrix
# 2025-10-28 15:23:04,242 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/cvrplib/VRP-set-D/Loggi-n1001-k31.vrp: CVRP with 1001 nodes
# 2025-10-28 15:23:04,242 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/cvrplib/VRP-set-D/Loggi-n1001-k31.vrp: CVRP with 1001 nodes
# 2025-10-28 15:23:05,440 - converter - INFO - Converted edge weights to 1001×1001 matrix
# 2025-10-28 15:23:05,440 - converter - INFO - Converted edge weights to 1001×1001 matrix
# 2025-10-28 15:23:08,038 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/cvrplib/VRP-set-D/Loggi-n401-k23.vrp: CVRP with 401 nodes
# 2025-10-28 15:23:08,038 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/cvrplib/VRP-set-D/Loggi-n401-k23.vrp: CVRP with 401 nodes
# 2025-10-28 15:23:08,188 - converter - INFO - Converted edge weights to 401×401 matrix
# 2025-10-28 15:23:08,188 - converter - INFO - Converted edge weights to 401×401 matrix
# 2025-10-28 15:23:09,405 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/cvrplib/VRP-set-D/ORTEC-n405-k18.vrp: CVRP with 405 nodes
# 2025-10-28 15:23:09,405 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/cvrplib/VRP-set-D/ORTEC-n405-k18.vrp: CVRP with 405 nodes
# 2025-10-28 15:23:09,551 - converter - INFO - Converted edge weights to 405×405 matrix
# 2025-10-28 15:23:09,551 - converter - INFO - Converted edge weights to 405×405 matrix
# 2025-10-28 15:23:10,972 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/cvrplib/VRP-set-D/Loggi-n601-k42.vrp: CVRP with 601 nodes
# 2025-10-28 15:23:10,972 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/cvrplib/VRP-set-D/Loggi-n601-k42.vrp: CVRP with 601 nodes
# 2025-10-28 15:23:11,370 - converter - INFO - Converted edge weights to 601×601 matrix
# 2025-10-28 15:23:11,370 - converter - INFO - Converted edge weights to 601×601 matrix
# 2025-10-28 15:23:13,247 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/cvrplib/VRP-set-D/Loggi-n501-k24.vrp: CVRP with 501 nodes
# 2025-10-28 15:23:13,247 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/cvrplib/VRP-set-D/Loggi-n501-k24.vrp: CVRP with 501 nodes
# 2025-10-28 15:23:13,523 - converter - INFO - Converted edge weights to 501×501 matrix
# 2025-10-28 15:23:13,523 - converter - INFO - Converted edge weights to 501×501 matrix
# 2025-10-28 15:23:15,169 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/cvrplib/VRP-set-D/Loggi-n901-k42.vrp: CVRP with 901 nodes
# 2025-10-28 15:23:15,169 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/cvrplib/VRP-set-D/Loggi-n901-k42.vrp: CVRP with 901 nodes
# 2025-10-28 15:23:15,920 - converter - INFO - Converted edge weights to 901×901 matrix
# 2025-10-28 15:23:15,920 - converter - INFO - Converted edge weights to 901×901 matrix
# 2025-10-28 15:23:18,278 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/cvrplib/VRP-set-D/ORTEC-n701-k64.vrp: CVRP with 701 nodes
# 2025-10-28 15:23:18,278 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/cvrplib/VRP-set-D/ORTEC-n701-k64.vrp: CVRP with 701 nodes
# 2025-10-28 15:23:18,703 - converter - INFO - Converted edge weights to 701×701 matrix
# 2025-10-28 15:23:18,703 - converter - INFO - Converted edge weights to 701×701 matrix
# 2025-10-28 15:23:20,680 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/cvrplib/VRP-set-D/ORTEC-n323-k21.vrp: CVRP with 323 nodes
# 2025-10-28 15:23:20,680 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/cvrplib/VRP-set-D/ORTEC-n323-k21.vrp: CVRP with 323 nodes
# 2025-10-28 15:23:20,762 - converter - INFO - Converted edge weights to 323×323 matrix
# 2025-10-28 15:23:20,762 - converter - INFO - Converted edge weights to 323×323 matrix
# 2025-10-28 15:23:21,803 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/cvrplib/VRP-set-D/ORTEC-n242-k12.vrp: CVRP with 242 nodes
# 2025-10-28 15:23:21,803 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/cvrplib/VRP-set-D/ORTEC-n242-k12.vrp: CVRP with 242 nodes
# 2025-10-28 15:23:21,864 - converter - INFO - Converted edge weights to 242×242 matrix
# 2025-10-28 15:23:21,864 - converter - INFO - Converted edge weights to 242×242 matrix
# 2025-10-28 15:23:22,768 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/cvrplib/VRP-set-D/Loggi-n601-k19.vrp: CVRP with 601 nodes
# 2025-10-28 15:23:22,768 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/cvrplib/VRP-set-D/Loggi-n601-k19.vrp: CVRP with 601 nodes
# 2025-10-28 15:23:23,095 - converter - INFO - Converted edge weights to 601×601 matrix
# 2025-10-28 15:23:23,095 - converter - INFO - Converted edge weights to 601×601 matrix
# 2025-10-28 15:23:25,094 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/cvrplib/VRP-set-D/ORTEC-n455-k41.vrp: CVRP with 455 nodes
# 2025-10-28 15:23:25,094 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/cvrplib/VRP-set-D/ORTEC-n455-k41.vrp: CVRP with 455 nodes
# 2025-10-28 15:23:25,269 - converter - INFO - Converted edge weights to 455×455 matrix
# 2025-10-28 15:23:25,269 - converter - INFO - Converted edge weights to 455×455 matrix
# ✅ Successfully processed 12/12 VRP files
# ✅ Successfully processed 12/12 VRP files

# %% [markdown]
# ## 4. Add All CVRPLIB Problems (Except Solomon)
#
# Process all remaining CVRPLIB instances, skipping the Vrp-Set-Solomon folder.
#
# **Processing Notes**:
# - Uses same step-by-step insertion as VRP-set-D
# - Depot information stored in nodes table with `is_depot` flag
# - No file tracking in this tutorial (use `insert_problem_atomic()` for production)

# %%
# Scan all CVRPLIB directories except Solomon
cvrplib_dir = project_root / "datasets_raw/cvrplib"

all_cvrplib_files = scanner.scan_files(
    directory=str(cvrplib_dir),
    patterns=['*.vrp', '*.txt'],  # .txt for Solomon format (which we'll skip)
    recursive=True
)

# Filter out Solomon instances and files we already processed
cvrplib_to_process = [
    f for f in all_cvrplib_files 
    if 'Vrp-Set-Solomon' not in f and 'VRP-set-D' not in f
]

print(f"📁 Total CVRPLIB files found: {len(all_cvrplib_files)}")
print(f"📁 After filtering (no Solomon, no VRP-set-D): {len(cvrplib_to_process)}")
print(f"\nDirectories to process:")

# Show which directories we're processing
dirs = set(Path(f).parent.name for f in cvrplib_to_process)
for d in sorted(dirs):
    count = sum(1 for f in cvrplib_to_process if Path(f).parent.name == d)
    print(f"   - {d}: {count} files")
# Out:
# 2025-10-28 15:23:26,811 - converter - INFO - Found 90 files
# 📁 Total CVRPLIB files found: 90
# 📁 After filtering (no Solomon, no VRP-set-D): 22
#
# Directories to process:
#    - Vrp-Set-Li: 12 files
#    - vrp-XXL: 10 files
# 📁 Total CVRPLIB files found: 90
# 📁 After filtering (no Solomon, no VRP-set-D): 22
#
# Directories to process:
#    - Vrp-Set-Li: 12 files
#    - vrp-XXL: 10 files

# %%
# Process remaining CVRPLIB files
cvrplib_success = 0
cvrplib_errors = []

for file_path in cvrplib_to_process:
    try:
        parsed = parser.parse_file(file_path)
        transformed = transformer.transform_problem(parsed)
        
        # Insert problem (NO file_path parameter)
        prob_id = db.insert_problem(transformed['problem_data'])
        db.insert_nodes(prob_id, transformed['nodes'])
        
        # Depot information is in nodes table (is_depot flag)
        
        cvrplib_success += 1
        if cvrplib_success % 20 == 0:
            print(f"   ✅ Processed {cvrplib_success}/{len(cvrplib_to_process)} CVRPLIB files...")
        
    except Exception as e:
        cvrplib_errors.append((Path(file_path).name, str(e)))

print(f"\n✅ Successfully processed {cvrplib_success}/{len(cvrplib_to_process)} CVRPLIB files")
if cvrplib_errors:
    print(f"❌ Errors: {len(cvrplib_errors)}")
    print(f"   Sample errors:")
    for name, error in cvrplib_errors[:3]:
        print(f"      - {name}: {error}")
# Out:
# 2025-10-28 15:23:26,887 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/cvrplib/vrp-XXL/Antwerp2.vrp: CVRP with 7001 nodes
# 2025-10-28 15:23:45,729 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/cvrplib/vrp-XXL/Antwerp1.vrp: CVRP with 6001 nodes
# 2025-10-28 15:23:45,729 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/cvrplib/vrp-XXL/Antwerp1.vrp: CVRP with 6001 nodes
# 2025-10-28 15:24:00,650 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/cvrplib/vrp-XXL/Leuven1.vrp: CVRP with 3001 nodes
# 2025-10-28 15:24:00,650 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/cvrplib/vrp-XXL/Leuven1.vrp: CVRP with 3001 nodes
# 2025-10-28 15:24:08,274 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/cvrplib/vrp-XXL/Leuven2.vrp: CVRP with 4001 nodes
# 2025-10-28 15:24:08,274 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/cvrplib/vrp-XXL/Leuven2.vrp: CVRP with 4001 nodes
# 2025-10-28 15:24:17,810 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/cvrplib/vrp-XXL/Brussels1.vrp: CVRP with 15001 nodes
# 2025-10-28 15:24:17,810 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/cvrplib/vrp-XXL/Brussels1.vrp: CVRP with 15001 nodes
# 2025-10-28 15:24:53,187 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/cvrplib/vrp-XXL/Ghent1.vrp: CVRP with 10001 nodes
# 2025-10-28 15:24:53,187 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/cvrplib/vrp-XXL/Ghent1.vrp: CVRP with 10001 nodes
# 2025-10-28 15:25:17,263 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/cvrplib/vrp-XXL/Brussels2.vrp: CVRP with 16001 nodes
# 2025-10-28 15:25:56,914 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/cvrplib/vrp-XXL/Flanders1.vrp: CVRP with 20001 nodes
# 2025-10-28 15:26:42,830 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/cvrplib/vrp-XXL/Ghent2.vrp: CVRP with 11001 nodes
# 2025-10-28 15:27:09,038 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/cvrplib/vrp-XXL/Flanders2.vrp: CVRP with 30001 nodes
# 2025-10-28 15:28:18,391 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/cvrplib/Vrp-Set-Li/Li_29.vrp: CVRP with 961 nodes
# 2025-10-28 15:28:20,875 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/cvrplib/Vrp-Set-Li/Li_21.vrp: CVRP with 561 nodes
# 2025-10-28 15:28:22,503 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/cvrplib/Vrp-Set-Li/Li_32.vrp: CVRP with 1201 nodes
# 2025-10-28 15:28:25,416 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/cvrplib/Vrp-Set-Li/Li_26.vrp: CVRP with 801 nodes
# 2025-10-28 15:28:27,717 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/cvrplib/Vrp-Set-Li/Li_28.vrp: CVRP with 881 nodes
# 2025-10-28 15:28:30,234 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/cvrplib/Vrp-Set-Li/Li_22.vrp: CVRP with 601 nodes
# 2025-10-28 15:28:32,334 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/cvrplib/Vrp-Set-Li/Li_27.vrp: CVRP with 841 nodes
# 2025-10-28 15:28:34,791 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/cvrplib/Vrp-Set-Li/Li_24.vrp: CVRP with 721 nodes
# 2025-10-28 15:28:37,150 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/cvrplib/Vrp-Set-Li/Li_31.vrp: CVRP with 1121 nodes
# 2025-10-28 15:28:40,379 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/cvrplib/Vrp-Set-Li/Li_23.vrp: CVRP with 641 nodes
#    ✅ Processed 20/22 CVRPLIB files...
# 2025-10-28 15:28:42,155 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/cvrplib/Vrp-Set-Li/Li_30.vrp: CVRP with 1041 nodes
# 2025-10-28 15:28:45,153 - converter - INFO - Successfully parsed /home/lucas_galdino/TCC-name_to_define/Routing_data/datasets_raw/cvrplib/Vrp-Set-Li/Li_25.vrp: CVRP with 761 nodes
#
# ✅ Successfully processed 22/22 CVRPLIB files

# %% [markdown]
# ## 5. Convert & Add MDVRP Instances (Cordeau Format)
#
# Now we'll demonstrate converting MDVRP instances from Cordeau format to TSPLIB95 and inserting them into the database **without creating intermediate files**.
#
# **Conversion Process**:
# 1. Parse Cordeau format → CordeauProblem object
# 2. Convert to TSPLIB95 text (in-memory string)
# 3. Write to temporary file (required by FormatParser.parse_file())
# 4. Parse with FormatParser → standard parsed_data structure
# 5. Transform and insert to database
# 6. Clean up temporary file
#
# **Why temp file?** `FormatParser.parse_file()` expects a file path, not raw text. The temp file is created and deleted in the same operation.

# %%
# Import Cordeau parser and converter
from src.tsplib_parser.cordeau.cordeau_parser import CordeauParser
from src.tsplib_parser.cordeau.cordeau_converter import CordeauConverter

# Initialize Cordeau parser and converter
cordeau_parser = CordeauParser(logger=logger)
cordeau_converter = CordeauConverter(logger=logger)

# Scan MDVRP directory
mdvrp_dir = project_root / "datasets_raw/umalaga/mdvrp/C-mdvrp"
mdvrp_files = list(mdvrp_dir.glob('p*'))  # p01, p02, ..., pr01, pr02, ...

print(f"📁 Found {len(mdvrp_files)} MDVRP files in {mdvrp_dir.name}/")
print(f"\nSample files:")
for f in sorted(mdvrp_files)[:5]:
    print(f"   - {f.name}")
# Out:
# 📁 Found 33 MDVRP files in C-mdvrp/
#
# Sample files:
#    - p01
#    - p02
#    - p03
#    - p04
#    - p05

# %%
# Example: Convert one MDVRP file (in-memory, no file output)
example_mdvrp = mdvrp_files[0]  # p01

# Step 1: Parse Cordeau format
cordeau_data = cordeau_parser.parse_file(str(example_mdvrp))
print(f"✅ Parsed Cordeau MDVRP: {example_mdvrp.name}")
print(f"   Customers: {cordeau_data.num_customers}")
print(f"   Vehicles: {cordeau_data.num_vehicles}")
print(f"   Depots: {cordeau_data.num_depots}")
print(f"   Problem type: {cordeau_data.type_name}")

# Step 2: Convert to TSPLIB95 format (in-memory)
tsplib_text = cordeau_converter.to_tsplib95(cordeau_data, output_path=None)
print(f"\n✅ Converted to TSPLIB95 format ({len(tsplib_text)} characters)")
print(f"\nFirst 300 characters of TSPLIB95 output:")
print(tsplib_text[:300] + "...")
# Out:
# 2025-10-28 15:28:47,303 - converter - INFO - Parsed p04: MDVRP with 100 customers, 2 depots, 8 vehicles
# ✅ Parsed Cordeau MDVRP: p04
#    Customers: 100
#    Vehicles: 8
#    Depots: 2
#    Problem type: MDVRP
#
# ✅ Converted to TSPLIB95 format (2086 characters)
#
# First 300 characters of TSPLIB95 output:
# NAME : p04
# COMMENT : Cordeau MDVRP instance | 8 vehicles | 100 customers | 2 depots
# TYPE : CVRP
# DIMENSION : 102
# EDGE_WEIGHT_TYPE : EUC_2D
# CAPACITY : 100
#
# NODE_COORD_SECTION
# 1 35.0 20.0
# 2 35.0 50.0
# 3 41.0 49.0
# 4 35.0 17.0
# 5 55.0 45.0
# 6 55.0 20.0
# 7 15.0 30.0
# 8 25.0 30.0
# 9 20.0 50.0
# 10 10.0 43.0
# 11 55....

# %%
# Step 3: Parse the converted TSPLIB95 text using FormatParser
# IMPORTANT: FormatParser.parse_file() expects a file path, not text
# We need to write the text to a temporary file first

import tempfile
from pathlib import Path

# Create a temporary file with the TSPLIB95 text
with tempfile.NamedTemporaryFile(mode='w', suffix='.vrp', delete=False) as tmp:
    tmp.write(tsplib_text)
    tmp_path = Path(tmp.name)

try:
    # Now parse the temporary file
    parsed_data = parser.parse_file(str(tmp_path))
    print(f"✅ Parsed converted TSPLIB95 text")
    
    # Update metadata
    parsed_data['metadata']['original_file'] = example_mdvrp.name
    parsed_data['metadata']['original_format'] = 'Cordeau MDVRP'
    
    print(f"   Extracted {len(parsed_data['nodes'])} nodes")
    print(f"   Problem type: {parsed_data['problem_data'].get('type')}")
    print(f"   Dimension: {parsed_data['problem_data'].get('dimension')}")
finally:
    # Clean up temporary file
    tmp_path.unlink()
# Out:
# 2025-10-28 15:28:47,323 - converter - INFO - Successfully parsed /tmp/tmpjtxw0g1a.vrp: CVRP with 102 nodes
# ✅ Parsed converted TSPLIB95 text
#    Extracted 102 nodes
#    Problem type: CVRP
#    Dimension: 102

# %%
# Step 5: Transform and insert into database
transformed_mdvrp = transformer.transform_problem(parsed_data)

# Note: Using insert_problem() without file_path
# For production with file tracking, use insert_problem_atomic() instead
mdvrp_id = db.insert_problem(transformed_mdvrp['problem_data'])
db.insert_nodes(mdvrp_id, transformed_mdvrp['nodes'])

print(f"✅ Inserted converted MDVRP {example_mdvrp.name} with ID: {mdvrp_id}")
print(f"   Nodes inserted: {len(transformed_mdvrp['nodes'])}")
print(f"\n🎉 Successfully converted MDVRP → TSPLIB95 → Database (no files created)!")
# Out:
# ✅ Inserted converted MDVRP p04 with ID: 216
#    Nodes inserted: 102
#
# 🎉 Successfully converted MDVRP → TSPLIB95 → Database (no files created)!

# %%
# Process all remaining MDVRP files
mdvrp_success = 1  # Already processed p04
mdvrp_errors = []

for mdvrp_file in mdvrp_files[1:]:  # Skip p04 (already done)
    try:
        # Step 1: Parse Cordeau format
        cordeau_data = cordeau_parser.parse_file(str(mdvrp_file))
        
        # Step 2: Convert to TSPLIB95 (in-memory)
        tsplib_text = cordeau_converter.to_tsplib95(cordeau_data, output_path=None)
        
        # Step 3: Write to temp file and parse with FormatParser
        import tempfile
        with tempfile.NamedTemporaryFile(mode='w', suffix='.vrp', delete=False) as tmp:
            tmp.write(tsplib_text)
            tmp_path = Path(tmp.name)
        
        try:
            parsed_data = parser.parse_file(str(tmp_path))
            parsed_data['metadata']['original_file'] = mdvrp_file.name
            parsed_data['metadata']['original_format'] = 'Cordeau MDVRP'
        finally:
            tmp_path.unlink()
        
        # Step 4: Transform and insert
        transformed = transformer.transform_problem(parsed_data)
        prob_id = db.insert_problem(transformed['problem_data'])
        db.insert_nodes(prob_id, transformed['nodes'])
        
        mdvrp_success += 1
        if mdvrp_success % 10 == 0:
            print(f"   ✅ Processed {mdvrp_success}/{len(mdvrp_files)} MDVRP files...")
        
    except Exception as e:
        mdvrp_errors.append((mdvrp_file.name, str(e)))
        if len(mdvrp_errors) <= 3:
            print(f"   ❌ Error: {mdvrp_file.name}: {e}")

print(f"\n✅ Successfully processed {mdvrp_success}/{len(mdvrp_files)} MDVRP files")
if mdvrp_errors:
    print(f"❌ Errors: {len(mdvrp_errors)}")
    print(f"   Sample errors:")
    for name, error in mdvrp_errors[:3]:
        print(f"      - {name}: {error}")
# Out:
# 2025-10-28 15:28:47,933 - converter - INFO - Parsed pr02: MDVRP with 96 customers, 4 depots, 2 vehicles
# 2025-10-28 15:28:47,937 - converter - INFO - Successfully parsed /tmp/tmpqd652dcs.vrp: CVRP with 100 nodes
# 2025-10-28 15:28:48,572 - converter - INFO - Parsed p06: MDVRP with 100 customers, 3 depots, 6 vehicles
# 2025-10-28 15:28:48,574 - converter - INFO - Successfully parsed /tmp/tmpg9vaqvo3.vrp: CVRP with 103 nodes
# 2025-10-28 15:28:49,198 - converter - INFO - Parsed pr04: MDVRP with 192 customers, 4 depots, 4 vehicles
# 2025-10-28 15:28:49,202 - converter - INFO - Successfully parsed /tmp/tmpdistw1yj.vrp: CVRP with 196 nodes
# 2025-10-28 15:28:50,329 - converter - INFO - Parsed p15: MDVRP with 160 customers, 4 depots, 5 vehicles
# 2025-10-28 15:28:50,336 - converter - INFO - Successfully parsed /tmp/tmp6vmg4300.vrp: CVRP with 164 nodes
# 2025-10-28 15:28:51,310 - converter - INFO - Parsed p11: MDVRP with 249 customers, 5 depots, 6 vehicles
# 2025-10-28 15:28:51,322 - converter - INFO - Successfully parsed /tmp/tmp326ja5w6.vrp: CVRP with 254 nodes
# 2025-10-28 15:28:52,635 - converter - INFO - Parsed p19: MDVRP with 240 customers, 6 depots, 5 vehicles
# 2025-10-28 15:28:52,651 - converter - INFO - Successfully parsed /tmp/tmpwrdrhyo0.vrp: CVRP with 246 nodes
# 2025-10-28 15:28:53,639 - converter - INFO - Parsed p13: MDVRP with 80 customers, 2 depots, 5 vehicles
# 2025-10-28 15:28:53,643 - converter - INFO - Successfully parsed /tmp/tmp5i8xylse.vrp: CVRP with 82 nodes
# 2025-10-28 15:28:54,185 - converter - INFO - Parsed p18: MDVRP with 240 customers, 6 depots, 5 vehicles
# 2025-10-28 15:28:54,190 - converter - INFO - Successfully parsed /tmp/tmpyycivyrz.vrp: CVRP with 246 nodes
# 2025-10-28 15:28:55,107 - converter - INFO - Parsed p17: MDVRP with 160 customers, 4 depots, 5 vehicles
# 2025-10-28 15:28:55,113 - converter - INFO - Successfully parsed /tmp/tmpxm0mkfpi.vrp: CVRP with 164 nodes
#    ✅ Processed 10/33 MDVRP files...
# 2025-10-28 15:28:55,815 - converter - INFO - Parsed pr01: MDVRP with 48 customers, 4 depots, 1 vehicles
# 2025-10-28 15:28:55,818 - converter - INFO - Successfully parsed /tmp/tmpg8tuo21n.vrp: CVRP with 52 nodes
# 2025-10-28 15:28:56,241 - converter - INFO - Parsed pr06: MDVRP with 288 customers, 4 depots, 6 vehicles
# 2025-10-28 15:28:56,246 - converter - INFO - Successfully parsed /tmp/tmpo55nilsv.vrp: CVRP with 292 nodes
# 2025-10-28 15:28:57,179 - converter - INFO - Parsed p05: MDVRP with 100 customers, 2 depots, 5 vehicles
# 2025-10-28 15:28:57,182 - converter - INFO - Successfully parsed /tmp/tmp3fxpkdjk.vrp: CVRP with 102 nodes
# 2025-10-28 15:28:57,762 - converter - INFO - Parsed p21: MDVRP with 360 customers, 9 depots, 5 vehicles
# 2025-10-28 15:28:57,772 - converter - INFO - Successfully parsed /tmp/tmp60qjwdaa.vrp: CVRP with 369 nodes
# 2025-10-28 15:28:58,925 - converter - INFO - Parsed p16: MDVRP with 160 customers, 4 depots, 5 vehicles
# 2025-10-28 15:28:58,929 - converter - INFO - Successfully parsed /tmp/tmpkp2ea18v.vrp: CVRP with 164 nodes
# 2025-10-28 15:28:59,513 - converter - INFO - Parsed pr09: MDVRP with 216 customers, 6 depots, 3 vehicles
# 2025-10-28 15:28:59,518 - converter - INFO - Successfully parsed /tmp/tmpnnekxt9e.vrp: CVRP with 222 nodes
# 2025-10-28 15:29:00,239 - converter - INFO - Parsed pr07: MDVRP with 72 customers, 6 depots, 1 vehicles
# 2025-10-28 15:29:00,241 - converter - INFO - Successfully parsed /tmp/tmploa10fof.vrp: CVRP with 78 nodes
# 2025-10-28 15:29:00,695 - converter - INFO - Parsed p22: MDVRP with 360 customers, 9 depots, 5 vehicles
# 2025-10-28 15:29:00,702 - converter - INFO - Successfully parsed /tmp/tmpyboaszmz.vrp: CVRP with 369 nodes
# 2025-10-28 15:29:02,346 - converter - INFO - Parsed pr03: MDVRP with 144 customers, 4 depots, 3 vehicles
# 2025-10-28 15:29:02,356 - converter - INFO - Successfully parsed /tmp/tmpwdvpukwk.vrp: CVRP with 148 nodes
# 2025-10-28 15:29:03,386 - converter - INFO - Parsed p20: MDVRP with 240 customers, 6 depots, 5 vehicles
# 2025-10-28 15:29:03,394 - converter - INFO - Successfully parsed /tmp/tmpl3eh5kzo.vrp: CVRP with 246 nodes
#    ✅ Processed 20/33 MDVRP files...
# 2025-10-28 15:29:04,513 - converter - INFO - Parsed p01: MDVRP with 50 customers, 4 depots, 4 vehicles
# 2025-10-28 15:29:04,517 - converter - INFO - Successfully parsed /tmp/tmp7oocbzfd.vrp: CVRP with 54 nodes
# 2025-10-28 15:29:05,135 - converter - INFO - Parsed pr05: MDVRP with 240 customers, 4 depots, 5 vehicles
# 2025-10-28 15:29:05,139 - converter - INFO - Successfully parsed /tmp/tmp8n36x6ec.vrp: CVRP with 244 nodes
# 2025-10-28 15:29:06,333 - converter - INFO - Parsed p12: MDVRP with 80 customers, 2 depots, 5 vehicles
# 2025-10-28 15:29:06,336 - converter - INFO - Successfully parsed /tmp/tmp9p_z9h6b.vrp: CVRP with 82 nodes
# 2025-10-28 15:29:06,972 - converter - INFO - Parsed p02: MDVRP with 50 customers, 4 depots, 2 vehicles
# 2025-10-28 15:29:06,973 - converter - INFO - Successfully parsed /tmp/tmposicuw7r.vrp: CVRP with 54 nodes
# 2025-10-28 15:29:07,494 - converter - INFO - Parsed p08: MDVRP with 249 customers, 2 depots, 14 vehicles
# 2025-10-28 15:29:07,501 - converter - INFO - Successfully parsed /tmp/tmpfccnrk07.vrp: CVRP with 251 nodes
# 2025-10-28 15:29:08,612 - converter - INFO - Parsed p03: MDVRP with 75 customers, 5 depots, 3 vehicles
# 2025-10-28 15:29:08,615 - converter - INFO - Successfully parsed /tmp/tmp_b6jzixv.vrp: CVRP with 80 nodes
# 2025-10-28 15:29:09,193 - converter - INFO - Parsed p14: MDVRP with 80 customers, 2 depots, 5 vehicles
# 2025-10-28 15:29:09,197 - converter - INFO - Successfully parsed /tmp/tmp5ruqtz1a.vrp: CVRP with 82 nodes
# 2025-10-28 15:29:09,739 - converter - INFO - Parsed pr08: MDVRP with 144 customers, 6 depots, 2 vehicles
# 2025-10-28 15:29:09,746 - converter - INFO - Successfully parsed /tmp/tmpdo4wggau.vrp: CVRP with 150 nodes
# 2025-10-28 15:29:10,489 - converter - INFO - Parsed p09: MDVRP with 249 customers, 3 depots, 12 vehicles
# 2025-10-28 15:29:10,497 - converter - INFO - Successfully parsed /tmp/tmpemcrgriv.vrp: CVRP with 252 nodes
# 2025-10-28 15:29:11,609 - converter - INFO - Parsed pr10: MDVRP with 288 customers, 6 depots, 4 vehicles
# 2025-10-28 15:29:11,614 - converter - INFO - Successfully parsed /tmp/tmpb1gd3tku.vrp: CVRP with 294 nodes
#    ✅ Processed 30/33 MDVRP files...
# 2025-10-28 15:29:12,789 - converter - INFO - Parsed p10: MDVRP with 249 customers, 4 depots, 8 vehicles
# 2025-10-28 15:29:12,795 - converter - INFO - Successfully parsed /tmp/tmpdk4c805z.vrp: CVRP with 253 nodes
# 2025-10-28 15:29:13,882 - converter - INFO - Parsed p23: MDVRP with 360 customers, 9 depots, 5 vehicles
# 2025-10-28 15:29:13,886 - converter - INFO - Successfully parsed /tmp/tmpm1e842yc.vrp: CVRP with 369 nodes
# 2025-10-28 15:29:15,221 - converter - INFO - Parsed p07: MDVRP with 100 customers, 4 depots, 4 vehicles
# 2025-10-28 15:29:15,226 - converter - INFO - Successfully parsed /tmp/tmp83xn0_ed.vrp: CVRP with 104 nodes
#
# ✅ Successfully processed 33/33 MDVRP files

# %% [markdown]
# ## 6. Query & Analyze Database
#
# Now let's explore what we've added to the database.
#
# **Query Capabilities**:
# - `get_problem_stats()`: Returns total count and breakdown by type
# - `query_problems()`: Filter by type, dimension, with pagination
# - `export_problem()`: Retrieves complete problem data including nodes
# - Direct SQL queries: Access edge_weight_matrices table for EXPLICIT problems

# %%
# Get database statistics
stats = db.get_problem_stats()

print("📊 Database Statistics")
print(f"   Total problems: {stats['total_problems']}")
print(f"\n   Problems by type:")
for type_info in stats['by_type']:
    print(f"      {type_info['type']}: {type_info['count']} "
          f"(avg dim: {type_info['avg_dimension']}, max: {type_info['max_dimension']})")

# Query specific problem types
print(f"\n📋 Sample TSP problems:")
tsp_problems = db.query_problems(problem_type='TSP', limit=5)
for p in tsp_problems:
    print(f"   - {p['name']}: {p['dimension']} nodes")

# Query ATSP problems (with EXPLICIT edge weights)
print(f"\n📋 Sample ATSP problems (with EXPLICIT edge weights):")
atsp_problems = db.query_problems(problem_type='ATSP', limit=5)
for p in atsp_problems:
    print(f"   - {p['name']}: {p['dimension']}×{p['dimension']} matrix")
# Out:
# 📊 Database Statistics
#    Total problems: 248
#
#    Problems by type:
#       TOUR: 40 (avg dim: 862.98, max: 5000)
#       HCP: 9 (avg dim: 3000.0, max: 5000)
#       ATSP: 19 (avg dim: 127.53, max: 443)
#       TSP: 113 (avg dim: 2659.15, max: 85900)
#       CVRP: 67 (avg dim: 2160.48, max: 30001)
#
# 📋 Sample TSP problems:
#    - berlin52: 52 nodes
#    - xray14012_2: 14012 nodes
#    - u1817: 1817 nodes
#    - berlin52: 52 nodes
#    - att532: 532 nodes
#
# 📋 Sample ATSP problems (with EXPLICIT edge weights):
#    - br17: 17×17 matrix
#    - ftv64: 65×65 matrix
#    - rbg403: 403×403 matrix
#    - rbg358: 358×358 matrix
#    - ftv70: 71×71 matrix

# %%
# Check edge_weight_matrices table
with duckdb.connect(str(db_path)) as conn:
    matrix_count = conn.execute(
        "SELECT COUNT(*) FROM edge_weight_matrices"
    ).fetchone()[0]
    
    print(f"\n📊 Edge Weight Matrices Table")
    print(f"   Total matrices stored: {matrix_count}")
    
    if matrix_count > 0:
        # Show sample matrix info
        sample = conn.execute("""
            SELECT 
                p.name,
                e.dimension,
                e.matrix_format,
                e.is_symmetric,
                LENGTH(e.matrix_json) as matrix_size_bytes
            FROM edge_weight_matrices e
            JOIN problems p ON e.problem_id = p.id
            LIMIT 5
        """).fetchall()
        
        print(f"\n   Sample matrices:")
        for name, dim, fmt, sym, size in sample:
            sym_str = "symmetric" if sym else "asymmetric"
            print(f"      - {name}: {dim}×{dim} {fmt} ({sym_str}, {size:,} bytes)")
# Out:
# 📊 Edge Weight Matrices Table
#    Total matrices stored: 35
#
#    Sample matrices:
#       - br17: 17×17 FULL_MATRIX (asymmetric, 1,024 bytes)
#       - bayg29: 29×29 UPPER_ROW (symmetric, 4,011 bytes)
#       - gr48: 48×48 LOWER_DIAG_ROW (symmetric, 11,446 bytes)
#       - fri26: 26×26 LOWER_DIAG_ROW (symmetric, 3,014 bytes)
#       - dantzig42: 42×42 LOWER_DIAG_ROW (symmetric, 7,508 bytes)

# %%
# Export a problem to verify structure
# We'll export the atsp_id from the br17.atsp we inserted earlier
# First, let's get the problem ID for br17.atsp
with duckdb.connect(str(db_path)) as conn:
    result = conn.execute("""
        SELECT id FROM problems WHERE name = 'br17' AND type = 'ATSP'
    """).fetchone()
    
    if result:
        br17_id = result[0]
        print(f"✅ Found br17.atsp with ID: {br17_id}")
    else:
        print("⚠️ br17.atsp not found in database. Using atsp_id from earlier.")
        br17_id = atsp_id  # Fallback to the variable from earlier

# Now export the problem
exported = db.export_problem(br17_id)

print(f"\n📦 Exported Problem Structure (ID {br17_id}):")
print(f"   Name: {exported['problem']['name']}")
print(f"   Type: {exported['problem']['type']}")
print(f"   Dimension: {exported['problem']['dimension']}")
print(f"   Nodes: {len(exported['nodes'])}")

# Check if edge_weight_matrix was retrieved from edge_weight_matrices table
# Note: export_problem() doesn't include edge matrices, we need to query separately
with duckdb.connect(str(db_path)) as conn:
    matrix_data = conn.execute("""
        SELECT matrix_json, dimension, is_symmetric 
        FROM edge_weight_matrices 
        WHERE problem_id = ?
    """, [br17_id]).fetchone()
    
    if matrix_data:
        import json
        matrix = json.loads(matrix_data[0])
        print(f"   ✅ Edge weight matrix: {matrix_data[1]}×{matrix_data[1]}")
        print(f"      Symmetric: {matrix_data[2]}")
        print(f"      Sample distance [0→1]: {matrix[0][1]}")
        print(f"      Sample distance [1→0]: {matrix[1][0]}")
        if matrix[0][1] != matrix[1][0]:
            print(f"      ✓ Matrix is asymmetric (ATSP)")
    else:
        print(f"   ℹ️  No edge weight matrix (coordinate-based problem)")

print(f"\n✅ Verified: EXPLICIT edge weights are properly stored and retrieved!")
# Out:
# ✅ Found br17.atsp with ID: 2
#
# 📦 Exported Problem Structure (ID 2):
#    Name: br17
#    Type: ATSP
#    Dimension: 17
#    Nodes: 17
#    ✅ Edge weight matrix: 17×17
#       Symmetric: False
#       Sample distance [0→1]: 3
#       Sample distance [1→0]: 3
#
# ✅ Verified: EXPLICIT edge weights are properly stored and retrieved!

# %% [markdown]
# ## Summary
#
# This notebook demonstrated the complete ETL pipeline workflow:
#
# ### ✅ What We Accomplished
#
# 1. **Parsed TSPLIB95 problems** - TSP (coordinate-based) and ATSP (EXPLICIT edge weights)
# 2. **Processed VRP instances** - CVRPLIB VRP-set-D with capacity constraints
# 3. **Batch processed** - All problems from `datasets_raw/problems/` and `cvrplib/` (except Solomon)
# 4. **Converted MDVRP** - Cordeau format → TSPLIB95 → Database (using temp files)
# 5. **Queried results** - Statistics, samples, and verified data integrity
#
# ### 🔑 Key Implementation Details
#
# **Edge Weight Storage**:
# - **EXPLICIT problems** (ATSP): Matrix stored in `edge_weight_matrices` table via manual SQL insertion
# - **Coordinate problems** (TSP, VRP): Distances computed on-demand from node x,y coordinates
# - Edge weight matrices converted from various formats (FULL_MATRIX, LOWER_ROW, etc.) to full 2D arrays
#
# **Database Insertion Pattern** (Educational Step-by-Step):
# ```python
# # Parse → Transform → Insert components separately
# parsed = parser.parse_file(file_path)
# transformed = transformer.transform_problem(parsed)
#
# # Insert problem (NO file_path parameter in insert_problem)
# prob_id = db.insert_problem(transformed['problem_data'])
# db.insert_nodes(prob_id, transformed['nodes'])
#
# # Handle edge matrices manually for EXPLICIT problems
# if 'edge_weight_matrix' in transformed:
#     conn.execute("INSERT INTO edge_weight_matrices ...")
# ```
#
# **Production Alternative**:
# For production code with file tracking and atomic transactions, use:
# ```python
# db.insert_problem_atomic(
#     problem_data=transformed['problem_data'],
#     nodes=transformed['nodes'],
#     file_path=str(file_path),
#     checksum=compute_checksum(file_path),
#     edge_weight_data={...}  # Optional for EXPLICIT problems
# )
# ```
#
# **Depot Handling**:
# - No separate depots table
# - Depot nodes identified by `is_depot=True` flag in nodes table
# - Works for VRP, CVRP, and MDVRP problems
#
# **MDVRP Conversion**:
# - Cordeau format → TSPLIB95 text (in-memory)
# - Requires temporary file for FormatParser (created and deleted per conversion)
# - Final data stored in same structure as native TSPLIB95 problems
#
# **Transformer Matrix Fix**:
# - Fixed Matrix access to use `value_at(i, j)` instead of `[i, j]`
# - Handles both Matrix objects and list-of-lists edge weights
# - Converts all formats to full dimension×dimension 2D arrays
#
# ### 📊 Database Schema
#
# **Tables**:
# - `problems`: Core problem metadata (name, type, dimension, capacity, etc.)
# - `nodes`: Node coordinates, demands, depot flags
# - `edge_weight_matrices`: Full 2D distance matrices for EXPLICIT problems
# - `solutions`: Optional solution tours
# - `file_tracking`: File paths and checksums for change detection (used by insert_problem_atomic)
#
# **Database Location**:
# ```
# datasets/db/routing_tutorial.duckdb
# ```
#
# You can query this database using DuckDB CLI or connect from other notebooks!
#
# ### 🎓 Educational Value
#
# This tutorial demonstrates:
# - ✅ Step-by-step data insertion (vs atomic transactions)
# - ✅ Manual edge matrix handling (vs automatic in insert_problem_atomic)
# - ✅ Format conversion patterns (Cordeau → TSPLIB95)
# - ✅ Direct SQL when needed (edge matrices, custom queries)
# - ✅ Error handling in batch processing
#
# For production pipelines, prefer `insert_problem_atomic()` for transaction safety and file tracking!
